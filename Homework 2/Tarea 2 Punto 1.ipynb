# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %%
def f(x,y):
    return x + 2*y

# %%
def Solucion(x):
    return -0.5*x - (1-np.exp(2*x))/4.

# %%
N = 10
t = np.linspace(0,1,N)

# %%
h = t[1] - t[0]

# %%
yext = Solucion(t)

# %%
plt.scatter(t,yext)
plt.show()

# %%
def GetEuler(x,y,h):
    
    for i in range(1,len(x)):
        
        k1 = f(x[i-1],y[i-1])
        y[i] = y[i-1] + h*k1

# %%
y1 = np.zeros_like(t)
y1[0] = 0

# %%
GetEuler(t,y1,h)

# %%
plt.plot(t,yext)
plt.plot(t,y1)
plt.show()

# %%
def GetEuler2(x,y,h):
    
    for i in range(1,len(x)):
        
        k1 = f(x[i-1],y[i-1])
        k2 = f(x[i-1]+h,y[i-1] + h*k1)
        
        y[i] = y[i-1] + 0.5*h*(k1+k2)

# %%
def f(x,y):
    return x + 2*y

# %%
y2 = np.zeros_like(t)
y2[0] = 0.

# %%
GetEuler2(t,y2,h)

# %%
plt.plot(t,yext)
plt.plot(t,y1,label='Euler1')
plt.plot(t,y2,label='Euler2')
plt.legend()
plt.show()

# %% [markdown]
# # Runge Kutta O3

# %%
def Runge_Kutta3(x,y,h):
    
    for i in range(1,len(x)):
        
        k1 = f(x[i-1],y[i-1])
        k2 = f(x[i-1]+(h/2),y[i-1] + (h/2)*k1)
        k3 = f(x[i-1]+h,y[i-1]-h*k1+2*h*k2)
        
        y[i] = y[i-1] + (h/6)*(k1+4*k2+k3)

# %%
y3 = np.zeros_like(t)
y3[0] = 0.

# %%
Runge_Kutta3(t,y3,h)

# %%
plt.plot(t,yext)
plt.plot(t,y1,label='Euler1')
plt.plot(t,y2,label='Euler2')
plt.plot(t,y3,label='Euler3')
plt.legend()

# %% [markdown]
# # Orden 4

# %%
def Runge_Kutta4(x,y,h):

    for i in range(1,len(x)):
        k1 = f(x[i-1], y[i-1])
        k2 = f(x[i-1]+(h/2),y[i-1] + (h/2)*k1)
        k3 = f(x[i-1]+(h/2),y[i-1] + (h/2)*k2)
        k4 = f(x[i-1] + h, y[i-1] + k3*h)
        
        y[i] = y[i-1] + (h/6)*(k1 + 2*k2 + 2*k3 + k4)

# %%
y4 = np.zeros_like(t)
y4[0] = 0.

# %%
Runge_Kutta4(t,y4,h)

# %%
plt.plot(t,yext)
plt.plot(t,y1,label='Euler1')
plt.plot(t,y2,label='Euler2')
plt.plot(t,y3,label='Euler3')
plt.plot(t,y4,label='Euler4')
plt.scatter(t,yext,label="Solution")
plt.legend()
plt.show()

# %% [markdown]
# Podemos ver que los métodos superiores mejoran la estabilidad y la consistencia, ya que oscilan menos respecto a la solución análitica y se acercan más al valor real. EL método de euler uno es altamente inconsistente, ya que no preserva el espacio de fase. Hemos comprobado de manera experimental, sin embargo demostraciones rigurosas requieren métodos de análisis númerico
